# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
prsa_data = pd.read_csv("PRSA_Data.csv", sep=",")
prsa_data.head()
# Out:
#    Unnamed: 0  No  SO2   NO2     CO         O3    PRES  RAIN   wd  WSPM  \
# 0           0   1  6.0  28.0  400.0  51.577659  1023.0   0.0  NNW   4.4
# 1           1   2  6.0  28.0  400.0  50.403851  1023.2   0.0    N   4.7
# 2           2   3 -1.0  19.0  400.0  54.923321  1023.5   0.0  NNW   5.6
# 3           3   4  8.0  14.0   -1.0  -1.000000  1024.5   0.0   NW   3.1
# 4           4   5  9.0  -1.0  300.0  54.296608  1025.2   0.0    N   2.0
#
#            AQI Label
# 0  Severely Polluted
# 1  Severely Polluted
# 2  Severely Polluted
# 3          Excellent
# 4   Heavily Polluted

# %%
prsa_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  35064 non-null  int64
#  1   No          35064 non-null  int64
#  2   SO2         35064 non-null  float64
#  3   NO2         35064 non-null  float64
#  4   CO          35064 non-null  float64
#  5   O3          35064 non-null  float64
#  6   PRES        35064 non-null  float64
#  7   RAIN        35064 non-null  float64
#  8   wd          35064 non-null  object
#  9   WSPM        35064 non-null  float64
#  10  AQI Label   35064 non-null  object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 2.9+ MB

# %%
prsa_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  35064 non-null  int64
#  1   No          35064 non-null  int64
#  2   SO2         35064 non-null  float64
#  3   NO2         35064 non-null  float64
#  4   CO          35064 non-null  float64
#  5   O3          35064 non-null  float64
#  6   PRES        35064 non-null  float64
#  7   RAIN        35064 non-null  float64
#  8   wd          35064 non-null  object
#  9   WSPM        35064 non-null  float64
#  10  AQI Label   35064 non-null  object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 2.9+ MB

# %%
prsa_data.describe()
# Out:
#          Unnamed: 0            No           SO2           NO2            CO  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17531.500000  17532.500000     18.058734     63.236861   1251.121692
# std    10122.249256  10122.249256     22.558126     39.109232   1269.033556
# min        0.000000      1.000000     -1.000000     -1.000000     -1.000000
# 25%     8765.750000   8766.750000      4.000000     34.000000    500.000000
# 50%    17531.500000  17532.500000     10.000000     58.000000    900.000000
# 75%    26297.250000  26298.250000     22.276800     87.000000   1500.000000
# max    35063.000000  35064.000000    282.000000    264.000000  10000.000000
#
#                  O3          PRES          RAIN          WSPM
# count  35064.000000  35064.000000  35064.000000  35064.000000
# mean      45.876835   1010.520250      0.067653      1.500217
# std       54.730861     26.289217      0.896833      1.105382
# ...

# %%
prsa_data[prsa_data == -1] = np.nan
prsa_data.head()
# Out:
#    Unnamed: 0  No  SO2   NO2     CO         O3    PRES  RAIN   wd  WSPM  \
# 0           0   1  6.0  28.0  400.0  51.577659  1023.0   0.0  NNW   4.4
# 1           1   2  6.0  28.0  400.0  50.403851  1023.2   0.0    N   4.7
# 2           2   3  NaN  19.0  400.0  54.923321  1023.5   0.0  NNW   5.6
# 3           3   4  8.0  14.0    NaN        NaN  1024.5   0.0   NW   3.1
# 4           4   5  9.0   NaN  300.0  54.296608  1025.2   0.0    N   2.0
#
#            AQI Label
# 0  Severely Polluted
# 1  Severely Polluted
# 2  Severely Polluted
# 3          Excellent
# 4   Heavily Polluted

# %%
sns.histplot(prsa_data.SO2)
# Out:
# <Axes: xlabel='SO2', ylabel='Count'>

# %%
sns.kdeplot(prsa_data.NO2)
# Out:
# <Axes: xlabel='NO2', ylabel='Density'>

# %%
prsa_data.RAIN[prsa_data.RAIN > 0]
# Out:
# 267      0.1
# 268      0.4
# 269      0.1
# 270      0.9
# 271      0.9
#         ...
# 34891    0.2
# 34892    0.7
# 34893    0.9
# 34894    0.4
# 34895    0.2
# Name: RAIN, Length: 1436, dtype: float64

# %%
is_rain = np.array(prsa_data.RAIN)
is_rain[is_rain > 0] = 1
prsa_data['IS_RAIN'] = is_rain
prsa_data.drop(['RAIN'], axis=1, inplace=True)
prsa_data.describe()
# Out:
#          Unnamed: 0            No           SO2           NO2            CO  \
# count  35064.000000  35064.000000  34489.000000  33994.000000  33252.000000
# mean   17531.500000  17532.500000     18.376481     65.258789   1319.353513
# std    10122.249256  10122.249256     22.609648     37.996088   1268.114331
# min        0.000000      1.000000      0.285600      1.642400    100.000000
# 25%     8765.750000   8766.750000      4.000000     36.000000    500.000000
# 50%    17531.500000  17532.500000     10.000000     60.000000    900.000000
# 75%    26297.250000  26298.250000     23.000000     88.000000   1600.000000
# max    35063.000000  35064.000000    282.000000    264.000000  10000.000000
#
#                  O3          PRES          WSPM       IS_RAIN
# count  32957.000000  35044.000000  35050.000000  35044.000000
# mean      48.873754   1011.097536      1.501215      0.040977
# std       55.113576     10.355247      1.104472      0.198240
# ...

# %%
sns.kdeplot(data=prsa_data, x="SO2", hue="AQI Label")
# Out:
# <Axes: xlabel='SO2', ylabel='Density'>

# %%
sns.kdeplot(data=prsa_data, x="CO", hue="AQI Label", log_scale=True)
# Out:
# <ipython-input-21-c5b2a0db864b>:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=prsa_data, x="CO", hue="AQI Label", log_scale=True)
# <Axes: xlabel='CO', ylabel='Density'>

# %%
bin_ranges = [0, 250, 320, 10000]
bin_names = [1, 2, 3]
prsa_data['CO_bin_custom_label'] = pd.cut(np.array(prsa_data['CO']),
                                               bins=bin_ranges, labels=bin_names)
prsa_data.head()
# Out:
#    Unnamed: 0  No  SO2   NO2     CO         O3    PRES   wd  WSPM  \
# 0           0   1  6.0  28.0  400.0  51.577659  1023.0  NNW   4.4
# 1           1   2  6.0  28.0  400.0  50.403851  1023.2    N   4.7
# 2           2   3  NaN  19.0  400.0  54.923321  1023.5  NNW   5.6
# 3           3   4  8.0  14.0    NaN        NaN  1024.5   NW   3.1
# 4           4   5  9.0   NaN  300.0  54.296608  1025.2    N   2.0
#
#            AQI Label  IS_RAIN CO_bin_custom_label
# 0  Severely Polluted      0.0                   3
# 1  Severely Polluted      0.0                   3
# 2  Severely Polluted      0.0                   3
# 3          Excellent      0.0                 NaN
# 4   Heavily Polluted      0.0                   2

# %%
prsa_data['CO_bin_custom_label'] = prsa_data['CO_bin_custom_label'].values.add_categories(0)
prsa_data['CO_bin_custom_label'] = prsa_data['CO_bin_custom_label'].fillna(0).astype(int)
prsa_data.head()
# Out:
#    Unnamed: 0  No  SO2   NO2     CO         O3    PRES   wd  WSPM  \
# 0           0   1  6.0  28.0  400.0  51.577659  1023.0  NNW   4.4
# 1           1   2  6.0  28.0  400.0  50.403851  1023.2    N   4.7
# 2           2   3  NaN  19.0  400.0  54.923321  1023.5  NNW   5.6
# 3           3   4  8.0  14.0    NaN        NaN  1024.5   NW   3.1
# 4           4   5  9.0   NaN  300.0  54.296608  1025.2    N   2.0
#
#            AQI Label  IS_RAIN  CO_bin_custom_label
# 0  Severely Polluted      0.0                    3
# 1  Severely Polluted      0.0                    3
# 2  Severely Polluted      0.0                    3
# 3          Excellent      0.0                    0
# 4   Heavily Polluted      0.0                    2

# %%
prsa_data.PRES[prsa_data.PRES <= 992] = 992
prsa_data.PRES[prsa_data.PRES >= 1034] = 1034
# Out:
# <ipython-input-146-5a60bf876b2e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prsa_data.PRES[prsa_data.PRES <= 992] = 992
# <ipython-input-146-5a60bf876b2e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prsa_data.PRES[prsa_data.PRES >= 1034] = 1034

# %%
sns.heatmap(prsa_data.isnull(), yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %%
undef = prsa_data.isnull().sum(axis=1)
undef[undef >= 2]
# Out:
# 3        2
# 276      3
# 435      2
# 459      2
# 555      2
#         ..
# 34880    4
# 34883    4
# 34885    4
# 35029    2
# 35030    2
# Length: 884, dtype: int64

# %%
prsa_data = prsa_data.drop(undef[undef >= 2].index, axis=0)

# %%
sns.heatmap(prsa_data.isnull(), yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %%
prsa_data.isnull().sum()
# Out:
# Unnamed: 0                0
# No                        0
# SO2                     281
# NO2                     702
# CO                     1028
# O3                     1300
# PRES                      0
# wd                        0
# WSPM                      0
# AQI Label                 0
# IS_RAIN                   0
# CO_bin_custom_label       0
# dtype: int64

# %%
prsa_data.SO2 = prsa_data.SO2.fillna(prsa_data.PRES.mean())

# %%
filler = prsa_data.O3[prsa_data.O3.isna()]

# %%
filler = prsa_data.O3[~prsa_data.O3.isna()].sample(n=len(filler)).set_axis(filler.index)

# %%
prsa_data.O3 = prsa_data.O3.fillna(filler)

# %%
sns.histplot(prsa_data.O3)
# Out:
# <Axes: xlabel='O3', ylabel='Count'>

# %%
prsa_data['O3'] = np.array(np.round((prsa_data['O3'])), dtype='int')
prsa_data.head()
# Out:
#    Unnamed: 0  No          SO2   NO2     CO  O3    PRES   wd  WSPM  \
# 0           0   1     6.000000  28.0  400.0  52  1023.0  NNW   4.4
# 1           1   2     6.000000  28.0  400.0  50  1023.2    N   4.7
# 2           2   3  1011.055986  19.0  400.0  55  1023.5  NNW   5.6
# 4           4   5     9.000000   NaN  300.0  54  1025.2    N   2.0
# 5           5   6     8.000000  17.0  300.0  54  1025.6    N   3.7
#
#            AQI Label  IS_RAIN  CO_bin_custom_label
# 0  Severely Polluted      0.0                    3
# 1  Severely Polluted      0.0                    3
# 2  Severely Polluted      0.0                    3
# 4   Heavily Polluted      0.0                    2
# 5   Heavily Polluted      0.0                    2

# %%
sns.histplot(prsa_data.SO2)
# Out:
# <Axes: xlabel='SO2', ylabel='Count'>

# %%
prsa_data.SO2 = np.log(prsa_data.SO2)

# %%
sns.histplot(prsa_data.SO2)
# Out:
# <Axes: xlabel='SO2', ylabel='Count'>

# %% [markdown]
# ## 1 При выполнении 3 и 5 заданий используйте другие методы визуализации. Найдите самый подходящий тип графика для каждого распределения.

# %%
import matplotlib.pyplot as plt

# %%
fig, axs = plt.subplots(4, 2, figsize=(10, 15))

for i, col in enumerate(prsa_data.select_dtypes(exclude='object').columns[2:]):
    sns.histplot(prsa_data[col], ax=axs[i//2][i%2])

plt.suptitle('Распределение численных атрибутов')
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(10, 15))

for i, col in enumerate(prsa_data.select_dtypes(exclude='object').columns[2:]):
    sns.kdeplot(prsa_data[col], ax=axs[i//2][i%2])

plt.suptitle('Распределение численных атрибутов')
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(10, 15))

for i, col in enumerate(prsa_data.select_dtypes(exclude='object').columns[2:]):
    sns.kdeplot(data=prsa_data, x=col, hue='AQI Label', ax=axs[i//2][i%2])

plt.suptitle('Совместное распределение численных атрибутов с целевой переменной')
plt.show()
# Out:
# <ipython-input-164-7741bb616131>:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=prsa_data, x=col, hue='AQI Label', ax=axs[i//2][i%2])
# <ipython-input-164-7741bb616131>:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=prsa_data, x=col, hue='AQI Label', ax=axs[i//2][i%2])
# <ipython-input-164-7741bb616131>:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=prsa_data, x=col, hue='AQI Label', ax=axs[i//2][i%2])

# %%
fig, axs = plt.subplots(4, 2, figsize=(10, 15))

for i, col in enumerate(prsa_data.select_dtypes(exclude='object').columns[2:]):
    sns.kdeplot(data=prsa_data, x=col, hue='AQI Label', ax=axs[i//2][i%2], warn_singular=False, log_scale=True)

plt.suptitle('Совместное распределение численных атрибутов с целевой переменной')
plt.show()

# %% [markdown]
# ## 2 При выполнении 6 задания мы явно подбирали руками границы диапазона для клиппинга. Реализуйте адаптивный клиппинг через процентили.

# %%
prsa_data = prsa_data.dropna(subset=['PRES'])
np.isnan(prsa_data.PRES).sum()
# Out:
# 0

# %%
sns.histplot(prsa_data.PRES)
# Out:
# <Axes: xlabel='PRES', ylabel='Count'>

# %%
# Рассчитываем процентили
lower_percentile = np.percentile(prsa_data.PRES, 1)
upper_percentile = np.percentile(prsa_data.PRES, 99)

# Ограничиваем значения атрибута новыми границами
Pres_ = prsa_data.PRES[((prsa_data.PRES > lower_percentile) &
                         (prsa_data.PRES < upper_percentile))]

sns.histplot(Pres_)
# Out:
# <Axes: xlabel='PRES', ylabel='Count'>

# %%
for col in prsa_data.select_dtypes(exclude='object').columns[2:]:
    lower_percentile = np.percentile(prsa_data[col], 1)
    upper_percentile = np.percentile(prsa_data[col], 99)

    prsa_data[col] = prsa_data[col][((prsa_data[col] > lower_percentile) &
                         (prsa_data[col] < upper_percentile))]

# %%
prsa_data.describe()
# Out:
#          Unnamed: 0            No           SO2  NO2   CO            O3  \
# count  34180.000000  34180.000000  27602.000000  0.0  0.0  32813.000000
# mean   17690.018929  17691.018929      2.657210  NaN  NaN     48.177399
# std    10089.433202  10089.433202      0.905094  NaN  NaN     50.980206
# min        0.000000      1.000000      0.826278  NaN  NaN      2.000000
# 25%     9120.750000   9121.750000      1.945910  NaN  NaN      4.000000
# 50%    17741.500000  17742.500000      2.564949  NaN  NaN     33.000000
# 75%    26413.250000  26414.250000      3.295837  NaN  NaN     73.000000
# max    35063.000000  35064.000000      5.075174  NaN  NaN    235.000000
#
#                PRES          WSPM  IS_RAIN  CO_bin_custom_label
# count  33322.000000  32259.000000      0.0          4118.000000
# mean    1011.059887      1.536334      NaN             1.585236
# std        9.929173      0.987501      NaN             0.492741
# ...

# %% [markdown]
# ## 3 Избавьтесь от оставшихся пропусков в данных. Самостоятельно выберите метод.

# %%
prsa_data
# Out:
#        Unnamed: 0     No       SO2  NO2  CO    O3    PRES   wd  WSPM  \
# 0               0      1  1.791759  NaN NaN  52.0  1023.0  NNW   4.4
# 1               1      2  1.791759  NaN NaN  50.0  1023.2    N   4.7
# 2               2      3       NaN  NaN NaN  55.0  1023.5  NNW   NaN
# 4               4      5  2.197225  NaN NaN  54.0  1025.2    N   2.0
# 5               5      6  2.079442  NaN NaN  54.0  1025.6    N   3.7
# ...           ...    ...       ...  ...  ..   ...     ...  ...   ...
# 35059       35059  35060  1.386294  NaN NaN  81.0  1011.9    N   2.0
# 35060       35060  35061  1.791759  NaN NaN  45.0  1012.3  WSW   1.0
# 35061       35061  35062  1.945910  NaN NaN  48.0  1012.8    N   1.1
# 35062       35062  35063  1.609438  NaN NaN  50.0  1012.9  NNE   1.0
# 35063       35063  35064  1.791759  NaN NaN  11.0  1012.6   NE   1.1
#
#                AQI Label  IS_RAIN  CO_bin_custom_label
# 0      Severely Polluted      NaN                  NaN
# ...

# %%
prsa_data.isna().sum()
# Out:
# Unnamed: 0                 0
# No                         0
# SO2                     6578
# NO2                    34180
# CO                     34180
# O3                      1367
# PRES                     858
# wd                         0
# WSPM                    1921
# AQI Label                  0
# IS_RAIN                34180
# CO_bin_custom_label    30062
# dtype: int64

# %%
sns.heatmap(prsa_data.isnull(), yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %%
prsa_data.isna().sum()
# Out:
# Unnamed: 0                 0
# No                         0
# SO2                     6578
# NO2                    34180
# CO                     34180
# O3                      1367
# PRES                     858
# wd                         0
# WSPM                    1921
# AQI Label                  0
# IS_RAIN                34180
# CO_bin_custom_label    30062
# dtype: int64

# %% [markdown]
# ## 4 Проведите нормализацию численных признаков. Выберите наиболее подходящий вид нормализации для каждого признака.

# %%
x = prsa_data.iloc[:,[2,3,4,5,6,8]]
prsa_data.iloc [:,[2,3,4,5,6,8]] = (x-x. min ())/ (x. max () - x. min ())

# %%
prsa_data.describe()
# Out:
#          Unnamed: 0            No           SO2  NO2   CO            O3  \
# count  34180.000000  34180.000000  27602.000000  0.0  0.0  32813.000000
# mean   17690.018929  17691.018929      0.430920  NaN  NaN      0.198186
# std    10089.433202  10089.433202      0.213019  NaN  NaN      0.218799
# min        0.000000      1.000000      0.000000  NaN  NaN      0.000000
# 25%     9120.750000   9121.750000      0.263511  NaN  NaN      0.008584
# 50%    17741.500000  17742.500000      0.409205  NaN  NaN      0.133047
# 75%    26413.250000  26414.250000      0.581224  NaN  NaN      0.304721
# max    35063.000000  35064.000000      1.000000  NaN  NaN      1.000000
#
#                PRES          WSPM  IS_RAIN  CO_bin_custom_label
# count  33322.000000  32259.000000      0.0          4118.000000
# mean       0.476379      0.287267      NaN             1.585236
# std        0.249477      0.197500      NaN             0.492741
# ...

# %% [markdown]
# ## 5 Постройте кореллограмму по всем численным столбцам датасета. Сделайте вывод о значимости признаков.

# %%
prsa_data
# Out:
#        Unnamed: 0     No       SO2  NO2  CO        O3      PRES   wd  WSPM  \
# 0               0      1  0.227231  NaN NaN  0.214592  0.776382  NNW  0.86
# 1               1      2  0.227231  NaN NaN  0.206009  0.781407    N  0.92
# 2               2      3       NaN  NaN NaN  0.227468  0.788945  NNW   NaN
# 4               4      5  0.322659  NaN NaN  0.223176  0.831658    N  0.38
# 5               5      6  0.294939  NaN NaN  0.223176  0.841709    N  0.72
# ...           ...    ...       ...  ...  ..       ...       ...  ...   ...
# 35059       35059  35060  0.131803  NaN NaN  0.339056  0.497487    N  0.38
# 35060       35060  35061  0.227231  NaN NaN  0.184549  0.507538  WSW  0.18
# 35061       35061  35062  0.263511  NaN NaN  0.197425  0.520101    N  0.20
# 35062       35062  35063  0.184321  NaN NaN  0.206009  0.522613  NNE  0.18
# 35063       35063  35064  0.227231  NaN NaN  0.038627  0.515075   NE  0.20
#
#                AQI Label  IS_RAIN  CO_bin_custom_label
# ...

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(prsa_data.drop(columns=['IS_RAIN', 'CO_bin_custom_label', 'Unnamed: 0', 'No', 'wd', 'AQI Label']).corr(), annot=True)

plt.title('Корреляционная матрица', fontsize=16)
plt.show()

# %% [markdown]
# ## 6 Визуализируйте связи между признаками. Сделайте вывод об их взаимозависимости.

# %%
plt.figure(figsize=(25, 15))
sns.pairplot(prsa_data.drop(columns=['IS_RAIN', 'CO_bin_custom_label', 'Unnamed: 0', 'No', 'wd', 'AQI Label']),  kind='reg',
             plot_kws={'line_kws':{'color':'red'}, 'scatter_kws': {'alpha': 0.02}})

plt.show()

# %%
prsa_data.drop(columns=['IS_RAIN', 'CO_bin_custom_label', 'Unnamed: 0', 'No', 'wd'. 'AQI Label'])
# Out:
#   File "<ipython-input-190-8373d0bfbcb3>", line 1
#     prsa_data.drop(columns=['IS_RAIN', 'CO_bin_custom_label', 'Unnamed: 0', 'No', 'wd'. 'AQI Label'])
#                                                                                         ^
# SyntaxError: invalid syntax
